# %%
import sys
sys.path.append('../Codes/library/')
from functions import*
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
plt.rcParams['text.usetex'] = True
Text_files_path = '/Users/robertomorantovar/Dropbox/Research/Evolution_Immune_System/Text_files/'

# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
data = np.array([2.0591, 2.0214, 2.0708, 2.0670, 2.0529, 2.0006, 1.9867, 2.2242, 2.0835, 1.6907, 1.7641, 1.9417, 1.9901, 1.8877])-1
print(data)
# Out:
# [1.0591 1.0214 1.0708 1.067  1.0529 1.0006 0.9867 1.2242 1.0835 0.6907
#  0.7641 0.9417 0.9901 0.8877]

# %%
zeta = 1/data

# %%
print(np.mean(zeta), np.std(zeta))
# Out:
# 0.5051789824168539 0.035341216711993195

# %%
zeta_H = (np.log(2)*3*2)/(6*1.8)

# %%
zeta_H
# Out:
# 0.3850817669777473
