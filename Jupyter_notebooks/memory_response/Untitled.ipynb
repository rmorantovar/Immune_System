# %%
import sys
sys.path.append('../../Codes/lib/')
from functions_1 import*
from classes import*

# %%
# %time
antigen = 'TACNSEYPNTTRAKCGRWYR'
energy_model = 'TCRen'
l = 20
ems = []
N = 100000
antigen_seqs = np.random.randint(0, 20, size = (N, 20))
for i in range(N):
    motif = get_motif(antigen_seqs[i], energy_model, '../../Codes/')*1.2
    em = 0
    for j in range(l):
        em+= np.min(motif[:, j], axis=0)
    ems.append(em)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 5.96 µs

# %%
# %time
plt.hist(ems, bins = np.linspace(-30, -12, 50)*1.2);
plt.yscale('log')
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.96 µs

# %%
# %%time
np.random.random(100000000);
# Out:
# CPU times: user 980 ms, sys: 256 ms, total: 1.24 s
# Wall time: 1.26 s

# %%
# %%time
np.random.rand(100000000);
# Out:
# CPU times: user 949 ms, sys: 204 ms, total: 1.15 s
# Wall time: 1.16 s

# %%
# %%time
for i in range(100000000):
    np.random.rand()
# Out:
# CPU times: user 34.9 s, sys: 251 ms, total: 35.2 s
# Wall time: 35.6 s

# %%
N = 100000000;

# %%
# %%time
np.random.randint(0, 20, size = (N, 20));
np.random.rand(N);
# Out:
# CPU times: user 31.4 s, sys: 7.81 s, total: 39.2 s
# Wall time: 40.6 s

# %%
# %%time
np.random.randint(0, 20, size = (N, 20));
for i in range(N):
    np.random.rand()
# Out:
# CPU times: user 1min 4s, sys: 7.49 s, total: 1min 11s
# Wall time: 1min 12s

# %%
for i, j in zip([1,2,3], [4, 5, 6]):
    print(i, j)
# Out:
# 1 4
# 2 5
# 3 6
