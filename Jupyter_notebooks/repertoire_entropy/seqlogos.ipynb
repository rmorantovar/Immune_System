# %% [markdown]
# # Plotting sequence logos
#
# This notebook shows how to display TCR sequence logos.
#
# The example data is from [Dash et al. Nature 2017](https://doi.org/10.1038/nature22383).

# %%
import numpy as np
import pandas as pd
import pyrepseq as rs
import pyrepseq.plotting as rsp
import matplotlib.pyplot as plt

# %%
cdr3_columns = {'alpha': 'cdr3_a_aa',
                'beta' : 'cdr3_b_aa'}

# %%
# !wget https://raw.githubusercontent.com/kmayerb/tcrdist3/master/dash_human.csv -O data/dash_human.csv > /dev/null 2>&1

# %%
d = pd.read_csv('data/dash_human.csv')

# %%
epitope = 'M1'
depitope = d[d['epitope']==epitope]
linkage, cluster = rs.hierarchical_clustering((depitope[cdr3_columns['alpha']],
                                               depitope[cdr3_columns['beta']]))

# %%
cluster_number, count = np.unique(cluster, return_counts=True)
for cl in cluster_number[count>3]:
    tcrs = depitope[cluster==cl]

    fig, axes = plt.subplots(ncols=6, nrows=1, sharey=True, figsize=(7.0, 0.4),
                         gridspec_kw=dict(width_ratios=(1, 3, 1, 1, 3, 1),
                                          wspace=0.1, hspace=0.5)
                         )
    chain = 'alpha'
    rsp.seqlogos_vj(tcrs, cdr3_columns[chain],
                                 'v_{c}_gene'.format(c=chain[0]),
                                 'j_{c}_gene'.format(c=chain[0]),
                   axes=axes[:3])
    chain = 'beta'
    rsp.seqlogos_vj(tcrs, cdr3_columns[chain],
                                 'v_{c}_gene'.format(c=chain[0]),
                                 'j_{c}_gene'.format(c=chain[0]),
                   axes=axes[3:]);
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 10
#       5 fig, axes = plt.subplots(ncols=6, nrows=1, sharey=True, figsize=(7.0, 0.4),
#       6                      gridspec_kw=dict(width_ratios=(1, 3, 1, 1, 3, 1),
#       7                                       wspace=0.1, hspace=0.5)
#       8                      )
#       9 chain = 'alpha'
# ---> 10 rsp.seqlogos_vj(tcrs, cdr3_columns[chain],
#      11                              'v_{c}_gene'.format(c=chain[0]),
#      12                              'j_{c}_gene'.format(c=chain[0]),
#      13                axes=axes[:3])
#      14 chain = 'beta'
#      15 rsp.seqlogos_vj(tcrs, cdr3_columns[chain],
#      16                              'v_{c}_gene'.format(c=chain[0]),
#      17                              'j_{c}_gene'.format(c=chain[0]),
#      18                axes=axes[3:])
#
# File ~/anaconda3/envs/roberto/lib/python3.9/site-packages/pyrepseq/plotting.py:412, in seqlogos_vj(df, cdr3_column, v_column, j_column, axes, **kwargs)
#     408 if axes is None:
#     409     fig, axes = plt.subplots(figsize=(0.2*max_length+2.0, 0.4), ncols=3,
#     410                          gridspec_kw=dict(width_ratios=(1, 0.2*max_length, 1), wspace=0.1),
#     411                          sharey=True)
# --> 412 seqlogos(seqs, axes[1], **kwargs)
#     413 for ax, counts in zip([axes[0], axes[2]], [counts_v, counts_j]):
#     414     previous_count = 0
#
# File ~/anaconda3/envs/roberto/lib/python3.9/site-packages/pyrepseq/plotting.py:371, in seqlogos(seqs, ax, **kwargs)
#     369 lengths = np.array([len(s) for s in seqs])
#     370 if(len(np.unique(lengths))>1):
# --> 371     seqs = align_seqs(seqs)
#     372 counts_mat = lm.alignment_to_matrix(seqs)
#     373 if ax is None:
#
# File ~/anaconda3/envs/roberto/lib/python3.9/site-packages/pyrepseq/plotting.py:343, in align_seqs(seqs)
#     341     seq_str += f'> seq {i}\n'
#     342     seq_str += f'{seq}\n'
# --> 343 child = subprocess.Popen(['mafft-linsi', '--quiet', '-'], stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#     344 child.stdin.write(seq_str.encode())
#     345 child_out = child.communicate()[0].decode('utf8')
#
# File ~/anaconda3/envs/roberto/lib/python3.9/subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/anaconda3/envs/roberto/lib/python3.9/subprocess.py:1837, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1835     if errno_num != 0:
#    1836         err_msg = os.strerror(errno_num)
# -> 1837     raise child_exception_type(errno_num, err_msg, err_filename)
#    1838 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mafft-linsi'

# %% [markdown]
# We can also use this procedure to plot individual sequences without any alignment).

# %%
fig, axes = plt.subplots(ncols=6, nrows=3, sharey=True, figsize=(7.0, 1.2),
                         gridspec_kw=dict(width_ratios=(1, 3, 1, 1, 3, 1),
                                          wspace=0.1, hspace=0.5)
                         )
for row, i in enumerate([32, 100, 50]):
    chain = 'alpha'
    rsp.seqlogos_vj(d.iloc[i:i+1], cdr3_columns[chain],
                                 'v_{c}_gene'.format(c=chain[0]),
                                 'j_{c}_gene'.format(c=chain[0]),
                   axes=axes[row, :3])
    chain = 'beta'
    rsp.seqlogos_vj(d.iloc[i:i+1], cdr3_columns[chain],
                                 'v_{c}_gene'.format(c=chain[0]),
                                 'j_{c}_gene'.format(c=chain[0]),
                   axes=axes[row, 3:])
