# %%
import sys
sys.path.append('../Codes/library/')
from functions import*
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit
plt.rcParams['text.usetex'] = True
Text_files_path = '/Users/robertomorantovar/Dropbox/Research/Evolution_Immune_System/Text_files/'

# %autosave 60
# Out:
# Autosaving every 60 seconds

# %%
#data = pd.read_excel(Text_files_path + 'Data/Briney_2019/powerlaw_briney_data.npz', header=1, sheet_name = 'Photoactivation')
data = np.load(Text_files_path + 'Data/Briney_2019/powerlaw_briney_data.npz', allow_pickle = True)
print(data['betas']-1)
# Out:
# [2.08879548 2.42587997 1.54620566 1.6291658  2.3135321  1.57994451
#  1.18880519 2.10171872 1.57426988]

# %%
betas = data['betas']-1
np.mean(1/betas)
# Out:
# 0.5743213274923754

# %%
np.std(1/betas)
# Out:
# 0.12930009497452852

# %%
np.var(1/betas)
# Out:
# 0.016718514560422098
